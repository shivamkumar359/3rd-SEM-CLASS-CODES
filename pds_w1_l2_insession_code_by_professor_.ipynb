# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamkumar359/3rd-SEM-CLASS-CODES/blob/main/pds_w1_l2_insession_code_by_professor_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Sum of numbers greater than 25 in tempt

tempt = [30,32,54,21,16,25,44,78]
avg = sum(tempt)/len(tempt)
count = 0
for t in tempt :
  if t>25:
    count+= t
print(count)

# %%
#2 Python projgramm to count even and odd in list

#list of numbers
list = [1,4,5,2,45,65,78,14,21,35,99,77,28,68]
even_count, odd_count = 0,0

# Iterating each number in list
for num in list :

  #checking condition
  if num % 2 == 0:
    even_count += 1

  else :
    odd_count += 1

print("Even number in list of numbers are :" , even_count)
print("Odd number in list of numbrs are : " , odd_count)

# %%
# 3.
x = 15
y = 4
res = x*y
print("multiple of x and y is: ", res)
# Out:
# multiple of x and y is:  60

# %%
# 4. Python programm to check if the number is odd or even
# A number is even if divided by 2 with 0 as reminder
#  A number is odd if divided by 2 and have 1 as reminder

num1 = input("Enter a number: ", )
print(type(num1))
num = int(num1)
print(type(num))

# Conditions
if (num % 2 ) == 0:
  print("number (",num, " ) is even number")

else:
  print("num1 (",num,") is a odd number ")
# Out:
# Enter a number: 75
# <class 'str'>
# <class 'int'>
# num1 ( 75 ) is a odd number

# %%
# 5.
list = [10,45,78,25,385,95]
print("Positioning of item 385 in list is: ",list.index(385,0,285))
print("Maximum in list is:",max(list))
print("Minimum in list is:",min(list))
# Out:
# Positioning of item 385 in list is:  4
# Maximum in list is: 385
# Minimum in list is: 10
