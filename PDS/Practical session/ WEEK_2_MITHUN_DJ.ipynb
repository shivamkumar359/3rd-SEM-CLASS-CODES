# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamkumar359/3rd-SEM-CLASS-CODES/blob/main/PDS/Practical%20session/%20WEEK_2_MITHUN_DJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Print("Python Revision")

print("=" * 40)

# %%
marks = [ 72,45,88,33,67]

# %%
print("Marks:", marks)
# Out:
# Marks: [72, 45, 88, 33, 67]

# %%
# indexing
print("First marks", marks[0])
print("Last marks :", marks[-1])
# Out:
# First marks 72
# Last marks : 67

# %%
# length
print("Number of students:",len(marks))
# Out:
# Number of students: 5

# %%
# for loop
print("\nPrining marks: ")
for mark in marks:
  print("",mark)
# Out:
# Prining marks:
#  72
#  45
#  88
#  33
#  67

# %%
for i in range(5):
  print("i =",i)
# Out:
# i = 0
# i = 1
# i = 2
# i = 3
# i = 4

# %%
# if condition
for mark in marks:
  if mark > 25:
    print("Mark:",mark,"pass")
# Out:
# Mark: 72 pass
# Mark: 45 pass
# Mark: 88 pass
# Mark: 33 pass
# Mark: 67 pass

# %%
for i in range(50):
  if i % 2 == 0:
    print(i,": is even \n")

  else :
    print(i, ": is a odd no \n")
# Out:
# 0 : is even
#
# 1 : is a odd no
#
# 2 : is even
#
# 3 : is a odd no
#
# 4 : is even
#
# 5 : is a odd no
#
# 6 : is even
#
# 7 : is a odd no
#
# 8 : is even
#
# 9 : is a odd no
#
# 10 : is even
#
# 11 : is a odd no
#
# 12 : is even
#
# 13 : is a odd no
#
# 14 : is even
#
# 15 : is a odd no
#
# 16 : is even
#
# 17 : is a odd no
#
# 18 : is even
#
# 19 : is a odd no
#
# 20 : is even
#
# 21 : is a odd no
#
# 22 : is even
#
# 23 : is a odd no
#
# 24 : is even
#
# 25 : is a odd no
#
# 26 : is even
#
# 27 : is a odd no
#
# 28 : is even
#
# 29 : is a odd no
#
# 30 : is even
#
# 31 : is a odd no
#
# 32 : is even
#
# 33 : is a odd no
#
# 34 : is even
#
# 35 : is a odd no
#
# 36 : is even
#
# 37 : is a odd no
#
# 38 : is even
#
# 39 : is a odd no
#
# 40 : is even
#
# 41 : is a odd no
#
# 42 : is even
#
# 43 : is a odd no
#
# 44 : is even
#
# 45 : is a odd no
#
# 46 : is even
#
# 47 : is a odd no
#
# 48 : is even
#
# 49 : is a odd no

# %%
# 4. BUbble sort method


numbers = [5,3,8,1,2,78,1,245,554,12,32,3,4,5,2]
print("Before:",numbers)
# Out:
# Before: [5, 3, 8, 1, 2, 78, 1, 245, 554, 12, 32, 3, 4, 5, 2]

# %%
n = len(numbers)
# Outer loop = number of passes
for i in range(n):

  # inner loop = compare neighbouting elements
  for j in range(0, n-i-1):

    # if left number is bigger
    if numbers[j] > numbers[j+1]:

      # swap
      numbers[j], numbers[j+1] = numbers[j+1], numbers[j]

print("After", numbers)
# Out:
# After [1, 1, 2, 2, 3, 3, 4, 5, 5, 8, 12, 32, 78, 245, 554]
