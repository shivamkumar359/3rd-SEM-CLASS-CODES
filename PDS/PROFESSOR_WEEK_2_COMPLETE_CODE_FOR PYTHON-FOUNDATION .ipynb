# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamkumar359/3rd-SEM-CLASS-CODES/blob/main/PDS/PROFESSOR_WEEK_2_COMPLETE_CODE_FOR%20PYTHON-FOUNDATION%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Python programm to create Tuples

# %%
# Empty tuple
my_tuple = ()
print(my_tuple)
# Out:
# ()

# %%
# tuple with integer value
