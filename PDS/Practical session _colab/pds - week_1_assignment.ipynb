# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamkumar359/3rd-SEM-CLASS-CODES/blob/main/PDS/Practical%20session%20_colab/pds%20-%20week_1_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Warm up

# %%
#  warm up

print("hello world! ")
# Out:
# hello world!

# %% [markdown]
# # 2. Literals

# %%
# 2. LITERALS
# ----------------------

integer_literal = 100
float_literal = 99.95
string_literal = "Python"
boolean_literal = True

# %%
print("Integer literal :", integer_literal)
print("Float literal ;", float_literal)
print("Boolean literal :", boolean_literal)
print("String literal :", string_literal)
# Out:
# Integer literal : 100
# Float literal ; 99.95
# Boolean literal : True
# String literal : Python

# %% [markdown]
# # 3. DATA TYPES

# %%
print("Data types")
print(type(integer_literal))
print(type(float_literal))
print(type(string_literal))
print(type(boolean_literal))
# Out:
# Data types
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# # 4. Functions

# %%
# 4. input function
name = input("Enter your name :")
age = input("Enter your age : ")
print("-----\n Welcome", name )
print("Your age is ", age)
# Out:
# Enter your name :15
# Enter your age : 15
# -----
#  Welcome 15
# Your age is  15

# %% [markdown]
# # 5. Define function

# %%
# 5. funtion user defined
def greet():
    print("Welcome to Python functions")

# %%
greet()
# Out:
# Welcome to Pyrton functions

# %% [markdown]
# # 6. Greet (add function )

# %%
def add(a,b):
  print("sum =", a+b)

# %%
print(add(5,7))
# Out:
# sum = 12
# None

# %% [markdown]
# # 7. Greet (sos function )

# %%
def sos(a,b):
  print("sos =", a*a +b*b)

# %%
sos(5,2)
# Out:
# sos = 29

# %%
# default parameter

def welcome(name="Guest"):
  print("Hello", name)

# %%
welcome()
# Out:
# Hello Guest
